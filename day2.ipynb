# %%
import pandas as pd

# %%
df= pd.read_csv("data/ex.csv",encoding='latin1')

# %% [markdown]
# #we can read few data from large about of data from given data
# => using df.head() gives first 5 data from the given data
# =? using df.tail() gives last 5 data from the given data

# %%
df.tail()
df.tail(9)
# Out:
#                                              description  \
# 17898  Measures in place to reduce its environmental ...
# 17899  Measures in place to reduce its environmental ...
# 17900  Measures in place to reduce its environmental ...
# 17901  Measures in place to reduce its environmental ...
# 17902  Measures in place to reduce its environmental ...
# 17903  Measures in place to reduce its environmental ...
# 17904  Measures in place to reduce its environmental ...
# 17905  Measures in place to reduce its environmental ...
# 17906  Measures in place to reduce its environmental ...
#
#                                              industry  level   size line_code  \
# 17898  Professional, scientific, & technical services      1  total  C4200.02
# 17899                         Computer systems design      2  total  C4200.02
# 17900                   Other professional scientific      2  total  C4200.02
# 17901               Administrative & support services      1  total  C4200.02
# ...

# %%
df.head()
df.head(4)
# Out:
#                   description industry  level             size line_code  \
# 0  Total number of businesses    total      0   619 employees       NaN
# 1  Total number of businesses    total      0  2049 employees       NaN
# 2  Total number of businesses    total      0  5099 employees       NaN
# 3  Total number of businesses    total      0   100+ employees       NaN
#
#    value                  Unit                  Footnotes
# 0  35562  Number of businesses  1 and 2 and 3 and 4 and 6
# 1   8796  Number of businesses  1 and 2 and 3 and 4 and 6
# 2   2529  Number of businesses  1 and 2 and 3 and 4 and 6
# 3   2100  Number of businesses  1 and 2 and 3 and 4 and 6

# %%
df.describe() #this gives us the value of sd mean min max percentile
# Out:
#               level         value
# count  17907.000000  17907.000000
# mean       1.404255    754.883677
# std        0.673516   2556.775922
# min        0.000000      0.000000
# 25%        1.000000     33.000000
# 50%        2.000000    126.000000
# 75%        2.000000    465.000000
# max        2.000000  48990.000000

# %%
df.info() # gives information of the data set no of rows columns data set used
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17907 entries, 0 to 17906
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   description  17907 non-null  object
#  1   industry     17907 non-null  object
#  2   level        17907 non-null  int64
#  3   size         17907 non-null  object
#  4   line_code    17860 non-null  object
#  5   value        17907 non-null  int64
#  6   Unit         17907 non-null  object
#  7   Footnotes    17907 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 1.1+ MB

# %% [markdown]
# # Data Selection

# %%
df["level"]
type(df["level"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # jUST LIKE SELECCTING ONE COLUMN WE CAN GET TWO OF THEM

# %%
df[["level","value"]]
# Out:
#        level  value
# 0          0  35562
# 1          0   8796
# 2          0   2529
# 3          0   2100
# 4          1   3756
# ...      ...    ...
# 17902      1    636
# 17903      1   1581
# 17904      1    390
# 17905      1    732
# 17906      0  26589
#
# [17907 rows x 2 columns]
